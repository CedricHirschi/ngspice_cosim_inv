# %%
import matplotlib.pyplot as plt
import numpy as np
import scienceplots

from common import NGSpiceRaw, FIG_WIDTH, figure_save

# %matplotlib widget

# %%
plt.style.use(["science", "grid"])
plt.style.use({
    'font.size': 14,                   # Slightly larger base font
    'axes.labelsize': 14,
    'axes.titlesize': 14,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'legend.fontsize': 12
})

# %%
data = NGSpiceRaw("simulation/tgate_tb.raw", live=False)
print("Fields:", data.names)
# Out:
# Loaded 1 plots from simulation/tgate_tb.raw
# Fields: ('time', 'v(vdd)', 'v(vss)', 'v(out)', 'v(in)', 'v(x1.ctrl_ni)', 'v(x1.x2.net1)', 'v(x1.ctrl_i)', 'i(vin)', 'i(vss)', 'i(vdd)', 'v(n.x1.xm1.nsg13_lv_pmos#NOI)', 'v(n.x1.xm1.nsg13_lv_pmos#GP)', 'v(n.x1.xm1.nsg13_lv_pmos#SI)', 'v(n.x1.xm1.nsg13_lv_pmos#DI)', 'v(n.x1.xm1.nsg13_lv_pmos#BP)', 'v(n.x1.xm1.nsg13_lv_pmos#BI)', 'v(n.x1.xm1.nsg13_lv_pmos#BS)', 'v(n.x1.xm1.nsg13_lv_pmos#BD)', 'v(n.x1.xm1.nsg13_lv_pmos#INT1)', 'v(n.x1.xm1.nsg13_lv_pmos#INT2)', 'v(n.x1.xm1.nsg13_lv_pmos#INT3)', 'v(n.x1.xm1.nsg13_lv_pmos#INT4)', 'v(n.x1.xm1.nsg13_lv_pmos#INT5)', 'v(n.x1.xm1.nsg13_lv_pmos#INT6)', 'v(n.x1.xm1.nsg13_lv_pmos#INT7)', 'v(n.x1.xm1.nsg13_lv_pmos#INT8)', 'v(n.x1.xm1.nsg13_lv_pmos#INT9)', 'v(n.x1.xm1.nsg13_lv_pmos#flow(RES1))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(SPLINE1))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(RES2))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(SPLINE2))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(RES3))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(SPLINE3))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(RES4))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(SPLINE4))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(RES5))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(SPLINE5))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(RES6))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(SPLINE6))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(RES7))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(SPLINE7))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(RES8))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(SPLINE8))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(RES9))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(SPLINE9))', 'v(n.x1.xm1.nsg13_lv_pmos#flow(NOII))', 'v(n.x1.xm1.nsg13_lv_pmos#implicit_equation_0)', 'v(n.x1.xm1.nsg13_lv_pmos#implicit_equation_1)', 'v(n.x1.xm1.nsg13_lv_pmos#implicit_equation_2)', 'v(n.x1.xm3.nsg13_lv_nmos#NOI)', 'v(n.x1.xm3.nsg13_lv_nmos#GP)', 'v(n.x1.xm3.nsg13_lv_nmos#SI)', 'v(n.x1.xm3.nsg13_lv_nmos#DI)', 'v(n.x1.xm3.nsg13_lv_nmos#BP)', 'v(n.x1.xm3.nsg13_lv_nmos#BI)', 'v(n.x1.xm3.nsg13_lv_nmos#BS)', 'v(n.x1.xm3.nsg13_lv_nmos#BD)', 'v(n.x1.xm3.nsg13_lv_nmos#INT1)', 'v(n.x1.xm3.nsg13_lv_nmos#INT2)', 'v(n.x1.xm3.nsg13_lv_nmos#INT3)', 'v(n.x1.xm3.nsg13_lv_nmos#INT4)', 'v(n.x1.xm3.nsg13_lv_nmos#INT5)', 'v(n.x1.xm3.nsg13_lv_nmos#INT6)', 'v(n.x1.xm3.nsg13_lv_nmos#INT7)', 'v(n.x1.xm3.nsg13_lv_nmos#INT8)', 'v(n.x1.xm3.nsg13_lv_nmos#INT9)', 'v(n.x1.xm3.nsg13_lv_nmos#flow(RES1))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(SPLINE1))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(RES2))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(SPLINE2))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(RES3))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(SPLINE3))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(RES4))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(SPLINE4))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(RES5))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(SPLINE5))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(RES6))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(SPLINE6))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(RES7))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(SPLINE7))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(RES8))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(SPLINE8))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(RES9))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(SPLINE9))', 'v(n.x1.xm3.nsg13_lv_nmos#flow(NOII))', 'v(n.x1.xm3.nsg13_lv_nmos#implicit_equation_0)', 'v(n.x1.xm3.nsg13_lv_nmos#implicit_equation_1)', 'v(n.x1.xm3.nsg13_lv_nmos#implicit_equation_2)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#NOI)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#GP)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#SI)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#DI)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#BP)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#BI)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#BS)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#BD)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#INT1)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#INT2)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#INT3)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#INT4)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#INT5)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#INT6)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#INT7)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#INT8)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#INT9)', 'v(n.x1.x2.xp0.nsg13_lv_pmos#flow(RES1))', 'v(n.x1.x2.xp0.nsg13_lv_pmos#flow(SPLINE1))', 'v(n.x1.x2.xp0.nsg13_lv_pmos#flow(RES2))', 'v(n.x1.x2.xp0.nsg13_lv_pmos#flow(SPLINE2))', 'v(n.x1.x2.xp0.nsg13_lv_pmos#flow(RES3))', 'v(n.x1.x2.xp0.nsg13_lv_pmos#flow(S ...

# %%
times = data['time']
vin = data['v(in)']
vout = data['v(out)']

# %%
plt.figure(figsize=(FIG_WIDTH, FIG_WIDTH * 0.5))
# plt.plot(times * 1e3, vin, color='blue')
plt.plot(times * 1e3, vout, color='red')
# plt.title('Input and Output Voltages')
plt.xlabel('Time [ms]')
plt.ylabel('Output Voltage [V]')
# plt.legend()
plt.tight_layout()
plt.show()

figure_save(plt.gcf(), "tgate_bleed")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
